# %%
# RRCP (19/09/2026): Derivadas
import numpy as np
import matplotlib.pyplot as plt

# %%
# Funcion
def f(x):
    return x**2

# %%
# Deribada de la funcion
def df(f):
    h = 0.000001
    return (f(x + h) - f(x))/h

# %%
# Graficar la funcion.
x = np.linspace(-10, 10, num = 1000)
y = f(x)
plt.plot(x,y)
plt.grid()

# %%
# Graficar la funcion con la derivada
plt.plot(x, y, 'b') # Azul
plt.plot(x, df(f), 'r') # Rojo
plt.grid()

# %% [markdown]
# ### EJEMPLO CON SENO

# %%
# Funcion seno
def func_sen(x):
    return np.sin(x)

# %%
# Derivada de la funcion seno
def df_sen(func_sen):
    h = 0.000001
    return (func_sen(x_s + h) - func_sen(x_s))/h

# %%
# Grafica de la funcion.
x_s = np.linspace(-10,10, num = 100)
y_s = func_sen(x_s)
plt.plot(x_s, y_s, 'b')
plt.grid()

# %%
# Graficar la funcion con la derivada.
plt.plot(x_s, y_s, 'b') # Azul
plt.plot(x_s, df_sen(func_sen), 'r') # Rojo
plt.grid()
