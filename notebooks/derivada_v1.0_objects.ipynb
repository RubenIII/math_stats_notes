# %%
# RRCP (23/09/2026): Derivadas usando clases y objetos.
import numpy as np
from math_utils.derivacion import Derivacion

# %%
derivador = Derivacion()

resultado = derivador.derivada_numerica(np.sin, 0)

print(resultado)
# Out:
# 0.9999999995833334
