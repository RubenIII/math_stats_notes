# %%
# RRCP (18/SEP/2026): Informacion de Comprobacion.
import sys

print(sys.executable)
print(sys.version)
# Out:
# /opt/anaconda3/envs/math_stats_notes/bin/python
# 3.11.16 (main, Aug 27 2026, 14:37:43) [Clang 20.1.8 ]
